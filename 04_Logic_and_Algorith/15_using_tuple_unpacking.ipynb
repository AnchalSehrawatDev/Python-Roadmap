# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorith/15_using_tuple_unpacking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    length, breadth = float(input("Enter length: ")), float(input("Enter breadth: "))
    print(f"Area: {length * breadth}")
except ValueError:
       print("Print valid number")
# Out:
# Enter length: N
# Print valid number
